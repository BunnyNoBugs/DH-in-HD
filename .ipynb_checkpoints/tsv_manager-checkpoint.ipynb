# %%
import pandas as pd

# %%
titles = pd.read_csv('title.akas.tsv/data.tsv', sep='\t', low_memory=False)
titles.head(10)
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Carmencita     DE       \N
# 1  tt0000001         2  Carmencita - spanyol tánc     HU       \N
# 2  tt0000001         3                 Καρμενσίτα     GR       \N
# 3  tt0000001         4                 Карменсита     RU       \N
# 4  tt0000001         5                 Carmencita     US       \N
# 5  tt0000001         6                 Carmencita     \N       \N
# 6  tt0000001         7                    カルメンチータ     JP       ja
# 7  tt0000002         1     Le clown et ses chiens     \N       \N
# 8  tt0000002         2          A bohóc és kutyái     HU       \N
# 9  tt0000002         3     Le clown et ses chiens     FR       \N
#
#          types     attributes isOriginalTitle
# 0           \N  literal title               0
# 1  imdbDisplay             \N               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# ...

# %%
titles = titles[titles['isOriginalTitle'] == '1']
titles
# Out:
#             titleId  ordering                                       title  \
# 5         tt0000001         6                                  Carmencita
# 7         tt0000002         1                      Le clown et ses chiens
# 19        tt0000003         5                              Pauvre Pierrot
# 23        tt0000004         1                                 Un bon bock
# 40        tt0000005         9                            Blacksmith Scene
# ...             ...       ...                                         ...
# 20771557  tt9916192         3  Danielle Darrieux: Il est poli d'être gai!
# 20771594  tt9916270         1                    Il talento del calabrone
# 20771807  tt9916460         2                                   Pink Taxi
# 20772076  tt9916678         2                                  Acelerados
# 20772121  tt9916720         5                                   The Nun 2
#
#          region language     types attributes isOriginalTitle
# ...

# %%
titles
# Out:
#           titleId                                       title     types  \
# 0       tt0000001                                  Carmencita  original
# 1       tt0000002                      Le clown et ses chiens  original
# 2       tt0000003                              Pauvre Pierrot  original
# 3       tt0000004                                 Un bon bock  original
# 4       tt0000005                            Blacksmith Scene  original
# ...           ...                                         ...       ...
# 484256  tt9916192  Danielle Darrieux: Il est poli d'être gai!  original
# 484257  tt9916270                    Il talento del calabrone  original
# 484258  tt9916460                                   Pink Taxi  original
# 484259  tt9916678                                  Acelerados  original
# 484260  tt9916720                                   The Nun 2  original
#
#           director  averageRating  numVotes
# 0        nm0005690            5.6    1592.0
# ...

# %%
actors
# Out:
#             titleId  ordering     nconst
# 11        tt0000005         1  nm0443482
# 12        tt0000005         2  nm0653042
# 16        tt0000007         1  nm0179163
# 17        tt0000007         2  nm0183947
# 21        tt0000008         1  nm0653028
# ...             ...       ...        ...
# 38430834  tt9916880         1  nm1483166
# 38430835  tt9916880         2  nm0254176
# 38430836  tt9916880         3  nm0286175
# 38430837  tt9916880         4  nm1052583
# 38430842  tt9916880         9  nm2676923
#
# [15589714 rows x 3 columns]

# %%
actors = cast[(cast['category'] == 'actor') | (cast['category'] == 'actress')]

# %%
new_actors = actors.groupby('titleId')['nconst'].apply(' '.join)

# %%
new_new_actors
# Out:
#                                                       actors
# titleId
# tt0000005                                nm0443482 nm0653042
# tt0000007                                nm0179163 nm0183947
# tt0000008                                          nm0653028
# tt0000009                      nm0063086 nm0183823 nm1309758
# tt0000011                                          nm3692297
# ...                                                      ...
# tt9916848            nm5519557 nm8825009 nm5262613 nm8690065
# tt9916850            nm5519557 nm8825009 nm5262613 nm8690065
# tt9916852            nm5519557 nm8825009 nm5262613 nm8690065
# tt9916856         nm3394271 nm10538650 nm10538646 nm10538647
# tt9916880  nm1469295 nm1483166 nm0254176 nm0286175 nm1052...
#
# [3808465 rows x 1 columns]

# %%
titles = titles.merge(new_new_actors, on='titleId', how='left')

# %%
titles
# Out:
#           titleId                                       title     types  \
# 0       tt0000001                                  Carmencita  original
# 1       tt0000002                      Le clown et ses chiens  original
# 2       tt0000003                              Pauvre Pierrot  original
# 3       tt0000004                                 Un bon bock  original
# 4       tt0000005                            Blacksmith Scene  original
# ...           ...                                         ...       ...
# 484256  tt9916192  Danielle Darrieux: Il est poli d'être gai!  original
# 484257  tt9916270                    Il talento del calabrone  original
# 484258  tt9916460                                   Pink Taxi  original
# 484259  tt9916678                                  Acelerados  original
# 484260  tt9916720                                   The Nun 2  original
#
#           director  averageRating  numVotes  \
# 0        nm0005690            5.6    1592.0
# ...

# %%
titles.to_csv('titles.tsv', sep = '\t')
